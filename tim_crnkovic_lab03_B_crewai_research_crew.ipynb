# %% [markdown]
# <a href="https://colab.research.google.com/github/sylvite/UCSD-Agentic-AI/blob/main/tim_crnkovic_lab03_B_crewai_research_crew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 03B: A CrewAI Research Crew — Context Handoff + Memory
#
# **Week 3 — Agentic AI: Building Autonomous Intelligent Systems**
#
# In Lab 03A you built reflection and memory *by hand*. Now you'll use a real framework, **CrewAI**, where **agents**, **tasks**, and **memory** are first-class building blocks. You'll build a three-agent research crew — a **researcher**, an **analyst**, and a **writer** — where each agent's output becomes the next agent's **context**. Then you'll turn on CrewAI's built-in **memory** and see how it lets the crew carry context *across runs*, not just within one.
#
# ## Introduction
#
# This lesson answers:
#
# - What is a CrewAI crew (Agents, Tasks, Crew, Process)?
# - How does one agent hand its work off to the next?
# - What is the difference between **task-local state** (context within a run) and **remembered context** (memory across runs)?
# - What does a framework give you that hand-writing the loop does not?
#
# ## Learning Goals
#
# After completing this lesson you will be able to:
#
# - Define **Agents** (role / goal / backstory) and **Tasks** (description / expected_output).
# - Chain tasks so each one's output becomes the next task's **`context`**.
# - Run a sequential **Crew** and read each task's output.
# - Enable CrewAI **memory** and explain task-local state vs. remembered context across runs.
#
# This lab is on the **API-key** track and talks to Gemini through CrewAI + LiteLLM.

# %% [markdown]
# ## What is a CrewAI crew?
#
# CrewAI models a workflow as a small team. You define **Agents** (each a persona with a `role`, `goal`, and `backstory`), give them **Tasks** (each a `description` + `expected_output`), and assemble them into a **Crew** that runs the tasks in order (`Process.sequential`). The magic is **`context`**: you list which earlier tasks a task depends on, and CrewAI feeds those outputs in automatically — that is the agent handoff.
#
# ```
#    topic
#      │
#      ▼
#    ┌──────────────┐  research brief
#    │  researcher  │──────────────┐
#    └──────────────┘              │  context
#                                  ▼
#                           ┌──────────────┐  analysis
#                           │   analyst    │──────────────┐
#                           └──────────────┘              │  context
#                                                         ▼
#                                                  ┌──────────────┐  final report
#                                                  │    writer    │────────────▶
#                                                  └──────────────┘
#    each task's output becomes the next task's `context`.
#    turn on Crew memory and that context can also persist ACROSS runs.
# ```

# %% [markdown]
# ## Use cases
#
# A sequential crew fits any task with clear, ordered phases:
#
# - **Research -> analysis -> writing** (this lab): gather, interpret, present.
# - **Draft -> review -> revise**: a writer, a critic, an editor.
# - **Plan -> build -> test**: a planner, a coder, a tester.
# - **Extract -> normalize -> report**: a data pipeline of specialist steps.
#
# If steps are *independent* rather than ordered, you would fan them out in parallel instead (Week 2); a crew is for handoffs.

# %% [markdown]
# ## Building blocks
#
# - **Agent** — a worker defined by `role`, `goal`, and `backstory` (always a senior/expert persona here).
# - **Task** — a `description` (what to do), an `expected_output` (the shape), and the `agent` that owns it.
# - **`context`** — the list of earlier tasks whose outputs feed this one (the handoff).
# - **Crew + Process** — the agents + tasks + an execution order (`sequential`).
# - **Memory (optional)** — CrewAI's built-in short-term / long-term / entity memory, which carries context across runs.
# - **An embedder** — memory stores and retrieves by similarity, so it needs an embedding model (we point it at Gemini).

# %% [markdown]
# ## Considerations for trustworthy crews
#
# - **Bound the crew.** More agents and hops mean more cost and more places to go wrong; add only the steps the task needs.
# - **Context is not free.** Every handoff injects the prior output into the next prompt — long chains grow the context fast.
# - **Memory is powerful and sticky.** Remembered context helps continuity but can also carry stale or wrong facts forward; know what is being persisted.
# - **Constrain outputs where it matters.** Use `expected_output` (and schemas) so a downstream agent receives a predictable shape.
# - **Keep handoffs inspectable.** Read each `task.output` so you can see exactly what each agent contributed.

# %% [markdown]
# ## Setup: add your Gemini API key as a Colab secret
#
# 1. Get a key from [Google AI Studio](https://aistudio.google.com/app/apikey).
# 2. In Colab, click the **key icon** in the left sidebar ("Secrets").
# 3. Add a new secret named **`GEMINI_API_KEY`** and paste your key as the value.
# 4. Toggle **"Notebook access"** on for that secret.
#
# The next cell installs CrewAI (which pulls in LiteLLM, the layer that lets CrewAI call Gemini). This is a larger install — give it a minute.

# %%
# !pip install -q crewai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.9/185.9 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 61.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.3/591.3 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.9/353.9 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 55.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.6/405.6 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 87.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.4/731.4 kB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.1/27.1 MB 20.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.42.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %% [markdown]
# > **Heads-up on the pip output:** you may see an `ERROR: pip's dependency resolver ...` line mentioning `bigframes` and `rich`. This is **expected in Colab and safe to ignore** — CrewAI upgrades `rich`, and Colab's preinstalled `bigframes` pins an older `rich`; this lab never uses `bigframes`, and the install still succeeded. If Colab shows a **"Restart session"** prompt after installing, click it (or **Runtime -> Restart session**) and re-run from the setup cell.

# %%
import os

from google.colab import userdata
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process, LLM

load_dotenv()

api_key = userdata.get("GEMINI_API_KEY")
if not api_key:
    raise RuntimeError("Missing GEMINI_API_KEY. Add it in Colab Secrets (key icon) and enable notebook access.")

# LiteLLM (under CrewAI) reads the key from this env var for gemini/* models.
os.environ["GEMINI_API_KEY"] = api_key

# The `gemini/` prefix routes to the Gemini API. NOTE: this lab uses gemini-2.5-flash, not the
# gemini-2.5-flash-lite the other labs use. A crew fires many larger, multi-step requests, and the
# lite model -- the cheapest and most heavily used -- is often overloaded (HTTP 503) for requests
# that size, while flash has the capacity to serve them reliably. num_retries adds a per-call retry
# as an extra cushion for the occasional transient blip.
llm = LLM(
    # caution - model 2.5-flash throws a 404 error - it is not available to new users
    #model="gemini/gemini-2.5-flash",
    model="gemini/gemini-3.1-flash-lite",
    api_key=api_key,
    temperature=0.3,
    num_retries=5,
)

# While CrewAI/LiteLLM is quietly retrying a 503, it still logs alarming red "ERROR" lines.
# Quiet those so the notebook output stays readable; our own retry messages (plain prints) still show.
import logging
for _noisy in ("crewai.flow.runtime", "LiteLLM", "litellm", "root"):
    logging.getLogger(_noisy).setLevel(logging.CRITICAL)

# ChromaDB's Google embedder (used by CrewAI memory) still imports the legacy google.generativeai
# package and prints a deprecation notice. It works fine; silence the notice to keep output clean.
import warnings
warnings.filterwarnings("ignore", message=r".*google\.generativeai.*")

# CrewAI can upload run "traces" to its hosted dashboard. We keep it off so nothing leaves this
# notebook and CrewAI stops printing its "Tracing Preference Saved" panel. (See the note by the run
# cell -- the dashboard is genuinely useful for your own later projects; flip this to "true" to try it.)
os.environ["CREWAI_TRACING_ENABLED"] = "false"

# Quick connectivity check. Gemini can return a transient 503 ("high demand") on any call,
# so we retry a few times, and if it still will not respond we warn instead of crashing.
import time

def _health_check(prompt, tries=4, wait=8):
    for attempt in range(1, tries + 1):
        try:
            return llm.call(prompt)
        except Exception as e:
            if "503" in str(e) and attempt < tries:
                print(f"  Model overloaded (503). Waiting {wait}s, then retrying ({attempt}/{tries})...")
                time.sleep(wait)
            else:
                raise

try:
    print(_health_check("Say 'Setup complete!' and nothing else."))
except Exception as e:
    print("Connectivity check could not complete (model may be busy):", str(e)[:120])
    print("That is OK -- num_retries retries a transient 503 when you run the crew below.")
# Out:
# Setup complete!

# %% [markdown]
# ## The three agents
#
# Each agent is a senior persona. They share the same model; what makes one a researcher and another a writer is the `role` / `goal` / `backstory`.

# %%
TOPIC = "the impact of AI agents on software development workflows"


researcher = Agent(
    role="Senior Research Analyst",
    goal="Gather a faithful, specific research brief on the topic.",
    backstory="You dig up the key facts, real challenges, and concrete examples; you cite concepts, not hype.",
    llm=llm,
    verbose=False,
)

analyst = Agent(
    role="Senior Strategy Analyst",
    goal="Turn research into ranked implications and clear recommendations.",
    backstory="You are opinionated and evidence-driven; you separate what matters from what does not.",
    llm=llm,
    verbose=False,
)

writer = Agent(
    role="Senior Technical Writer",
    goal="Turn analysis into a polished, readable short report.",
    backstory="You write tight, engaging prose for a general audience; no jargon dumps.",
    llm=llm,
    verbose=False,
)

# %% [markdown]
# **Add a fourth agent. Insert a "Senior Fact-Checker"** task between the researcher and the analyst that flags any claim the brief can't support; feed it forward with context.

# %%
fact_checker = Agent(
    role="Senior Fact-Checker",
    goal="Flag any claims made in the research brief that are not supported by fact.",
    backstory="You act dispassionately, logically and without bias when deciding which claims in the research brief may not be supporable.",
    llm=llm,
    verbose=False,
)

# %% [markdown]
# ## The three tasks -- and the handoff via `context`
#
# Each task's `description` follows the Role / Context / Task / Constraints / Format shape. The part that makes this a *crew* and not three separate calls is the **`context=[...]`** argument on each `Task` -- that list **is** the handoff.
#
# When you write `context=[research_task]` on the analyst's task, CrewAI takes whatever `research_task` produced and **injects it into the analyst's prompt automatically**. You never copy the brief across by hand; you just name the upstream task. The writer names both earlier tasks, so it receives both outputs.
#
# Reading the `context=` lines top to bottom is the wiring diagram of the crew:
#
# ```
# research_task    context=[]                          -> runs first; no upstream input
#                        |
#                        |  its output is injected as context
#                        v
# analysis_task    context=[research_task]             -> sees the researcher's brief
#                        |
#                        |  both outputs injected
#                        v
# writing_task     context=[research_task,             -> sees BOTH the brief
#                           analysis_task]                 and the analysis
# ```
#
# So the handoff is declarative: instead of passing arguments between function calls, each task *declares which earlier tasks it depends on*, and CrewAI threads the outputs through. The topic is embedded directly in the first task, so we call `kickoff()` with no templated inputs.

# %% [markdown]
# **Structured handoff**. Give analysis_task an output_pydantic model so the writer receives typed, predictable analysis instead of prose.

# %%
from pydantic import BaseModel, Field
from typing import List
from crewai import Task

class AnalysisOutput(BaseModel):
    executive_summary: str = Field(
        description="Executive summary consisting of exactly 2 sentences."
    )

    key_implications: List[str] = Field(
        min_length=3,
        max_length=3,
        description="Exactly 3 key implications, ranked by impact (highest first). "
                    "Each item should be a concise statement backed with reasoning."
    )

    recommendations: List[str] = Field(
        min_length=2,
        max_length=2,
        description="Exactly 2 actionable recommendations."
    )

# %%
research_task = Task(
    description=f"""# Context
You are the first step; the analyst and writer build on your brief.

# Task
Produce a concise research brief on the topic in the Input section.

# Constraints
- Cover key facts, main challenges, and 2-3 notable examples.
- Be specific; cite concepts, not URLs.

# Format
Short sections with clear headers.

# Input (topic)
{TOPIC}""",
    expected_output="A structured research brief with clear section headers.",
    agent=researcher,
)

# the fourth task: fact-checking, inserted at this spot
fact_checking_task = Task(
    description=f"""# Context
The researcher's brief is available to you as context.

# Task
Produce a report of claims made in the researcher's bried that may not be supporable by fact.

# Constraints
- Identify the claims that are being flagged as dubious with regard to factuality.
- Provide reasoning for each dubious claim as to why it was flagged as such.

# Format
Bullet points of each dubious claim and the reason(s) for said claim being flagged.

# Input (topic)
{TOPIC}""",
    expected_output="A set of bullet points of dubious claims and reasonings.",
    agent=fact_checker,
    context=[research_task],
)

'''
analysis_task = Task(
    description="""# Context
The researcher's brief AND fact-checking report are available to you as context.

# Task
Analyze the research and the list of claims flagged as dubious by the fact-checker, if any, and draw the most important implications and recommendations.

# Constraints
- Rank implications by impact; back each claim with reasoning.

# Format
Executive Summary (2 sentences), Key Implications (3 bullets), Recommendations (2 bullets).""",
    expected_output="A ranked analysis with a summary, implications, and recommendations.",
    agent=analyst,
    context=[research_task, fact_checking_task],
)
'''
# analysis task with pydantic Model and schema
analysis_task = Task(
    description="""# Context
The researcher's brief AND fact-checking report are available to you as context.

# Task
Analyze the research and the list of claims flagged as dubious by the fact-checker (if any).
Draw the most important implications and recommendations.

# Strict Requirements
- Rank implications by impact (highest first).
- Back each implication with clear reasoning.
- Be concise and professional.

You MUST output valid JSON that strictly follows the AnalysisOutput schema.
Do not add any extra text, explanations, or markdown outside the JSON.""",

    expected_output="""A structured AnalysisOutput object containing:
- executive_summary (exactly 2 sentences)
- key_implications (exactly 3 items)
- recommendations (exactly 2 items)""",

    output_pydantic=AnalysisOutput,
    agent=analyst,
    context=[research_task, fact_checking_task],
)

writing_task = Task(
    description="""# Context
The research brief, the fact-checking report AND the analysis are available to you as context.

# Task
Write a polished, publication-ready short report that combines them for a general audience.

# Constraints
- 200-300 words; clear and engaging; no jargon dumps.

# Format
A title, then 2-3 short paragraphs.""",
    expected_output="A short titled report of 200-300 words.",
    agent=writer,
    context=[research_task, fact_checking_task, analysis_task],
)

# %% [markdown]
# ## A note on 503 "model overloaded" errors
#
# Gemini can return a transient **503 ("high demand")** when a model is busy. Two choices keep this lab robust:
#
# 1. **Model choice:** this lab uses `gemini-2.5-flash` (see setup). A crew fires many larger requests, and the cheaper `gemini-2.5-flash-lite` is frequently overloaded for that load, while `flash` has the capacity to serve it.
# 2. **Per-call retry:** `num_retries=5` on the `LLM` retries an individual call on a transient blip before it can fail the crew.
#
# If Gemini has a broad capacity event, calls can still fail -- that is a server-side outage, not a bug. Wait a few minutes and run the cell again.

# %% [markdown]
# ## Run the crew
#
# `Process.sequential` runs the tasks in order and threads the `context` through. After the run, each task's result is on `task.output` — read them to see exactly what each agent handed off.
#
# > **Async note (Colab):** Colab already runs an `asyncio` event loop, and this version of CrewAI refuses a *synchronous* `crew.kickoff()` from inside a running loop. So we use the async entry point **`await crew.kickoff_async()`** with top-level `await` — exactly the pattern from the async lab. (In a plain `.py` script with no running loop, `crew.kickoff()` works directly.)
#
# > **Aside — CrewAI's tracing dashboard:** CrewAI can upload a step-by-step trace of each run (every agent, the exact prompts and responses, token counts, latency) to a hosted web dashboard for debugging. We keep it **off** in this lab (`CREWAI_TRACING_ENABLED=false` in setup) so nothing leaves your notebook and the output stays clean — everything you need is printed inline below. For your own real projects it is worth a look: set `tracing=True` on the `Crew` (it needs a free CrewAI account) to inspect runs in the UI.

# %%
crew = Crew(
    agents=[researcher, fact_checker, analyst, writer],
    tasks=[research_task, fact_checking_task, analysis_task, writing_task],
    process=Process.sequential,
    verbose=False,
)

try:
    await crew.kickoff_async()

    print("=== RESEARCH BRIEF (researcher) ===")
    print(research_task.output.raw)
    print("=== FACT-CHECKING REPORT (fact_checker) ===")
    print(fact_checking_task.output.raw)
    print("\n=== ANALYSIS (analyst -- read the brief via context) ===")
    print(analysis_task.output.raw)
    print("\n=== FINAL REPORT (writer -- read both via context) ===")
    print(writing_task.output.raw)
except Exception as e:
    if "503" in str(e):
        print("Gemini is under heavy load right now (repeated 503s) and the crew could not finish.")
        print("This is a transient, server-side capacity issue -- not a bug in your code or this lab.")
        print("Wait a few minutes and re-run this cell; single calls usually recover quickly.")
    else:
        raise
# Out:
# === RESEARCH BRIEF (researcher) ===
# ### Research Brief: AI Agents in Software Development Workflows
#
# #### Overview
# AI agents represent a shift from "copilot" models (which suggest code snippets) to "autonomous" models (which execute multi-step tasks). Unlike traditional IDE extensions, agents possess agency to navigate file systems, execute terminal commands, run test suites, and iterate based on feedback loops, effectively acting as junior-level developers.
#
# #### Key Facts
# *   **Agentic Loops:** The core mechanism is the "ReAct" (Reasoning + Acting) pattern. Agents decompose a high-level prompt into a sequence of sub-tasks, execute them, observe the output, and self-correct if the code fails to compile or pass tests.
# *   **Context Window Management:** Agents utilize RAG (Retrieval-Augmented Generation) to index entire codebases. This allows them to understand cross-file dependencies, which is critical for refactoring or implementing features that span multiple modules.
# *   **Tool Use:** Agents are equipped with "tools" (e.g., language servers, shell access, GitHub API, browser automation). This allows them to move beyond text generation into actual system interaction.
#
# #### Main Challenges
# *   **Non-Deterministic Outcomes:** Because agents rely on probabilistic LLMs, the same prompt may yield different code structures or logic, complicating version control and auditability.
# *   **The "Context Bloat" Problem:** As codebases grow, providing the agent with relevant context without exceeding token limits or introducing "noise" (irrelevant files) remains a significant technical hurdle.
# *   **Security and Governance:** Granting agents write-access to repositories and execution environments introduces risks regarding unauthorized code injection, dependency poisoning, and the accidental deletion of critical infrastructure configurations.
# *   **Integration Debt:** Organizations struggle to integrate agents into existing CI/CD pipelines. If an agent commits code that breaks a build, the debugging process often takes longer than if the code had been written manually, due to the complexity of the agent's generated logic.
#
# #### Notable Examples
# *   **Devin (Cognition AI):** Positioned as the first "AI Software Engineer," Devin demonstrates the ability to autonomously plan and execute complex engineering tasks, such as migrating codebases, debugging production issues, and training its own models, by managing its own shell and browser.
# *   **OpenDevin (Open Source):** An open-source initiative that mirrors the autonomous capabilities of proprietary agents. It allows developers to build and deploy agents that can interact with the local environment, demonstrating the shift toward modular, customizable agentic workflows.
# *   **Cursor (IDE Integration):** While technically an IDE, Cursor utilizes an agentic backend that allows users to perform "Composer" tasks. It can modify multiple files simultaneously based on a natural language prompt, effectively acting as an agent that manages the state of the entire project workspace rather than just the current file.
#
# #### Analyst Perspective
# The transition from *code completion* to *agentic workflows* marks a move toward "Intent-Based Development." The developer’s role is evolving from a writer of syntax to an architect of constraints and a reviewer of autonomous outputs. The primary bottleneck is no longer the generation of code, but the verification of agent-generated logic.
# === FACT-CHECKING REPORT (fact_checker) ===
# As a Senior Fact-Checker, I have reviewed the provided research brief. While the document accurately reflects current industry trends and terminology, the following claims are flagged as potentially unsupported or factually problematic:
#
# *   **Claim: Devin "demonstrates the ability to... [train] its own models."**
#     *   **Reasoning:** This claim is unsubstantiated. While Cognition AI’s marketing materials and demonstrations showcase Devin’s ability to perform software engineering tasks like debugging, refactoring, and environment management, there is no verified public evidence or technical documentation confirming that Devin possesses the architectural capability to autonomously train its own machine learning models. Training models requires massive computational resources, specific data pipelines, and hyperparameter tuning that exceeds the scope of a standard software engineering agent.
#
# *   **Claim: Agents "effectively [act] as junior-level developers."**
#     *   **Reasoning:** This is a subjective analogy rather than a factual statement. While agents can perform discrete tasks, they lack the professional judgment, long-term accountability, and nuanced understanding of business requirements that define a human junior developer. Equating AI performance to a specific human job title is a qualitative assessment that varies wildly based on the complexity of the codebase and the specific agentic framework, making it an unsupported generalization.
#
# *   **Claim: Agents "effectively [act] as an agent that manages the state of the entire project workspace rather than just the current file [in Cursor]."**
#     *   **Reasoning:** This claim conflates "agentic behavior" with "IDE-level orchestration." While Cursor’s "Composer" feature allows for multi-file edits, it operates within the constraints of the IDE's existing file-system awareness and user-defined scope. Describing this as "managing the state of the entire project workspace" is an overstatement; the agent does not possess independent agency over the project's state, architecture, or lifecycle outside of the specific commands initiated by the user within the IDE environment.
#
# *   **Claim: "The primary bottleneck is no longer the generation of code, but the verification of agent-generated logic."**
#     *   **Reasoning:** This is an unsupported assertion presented as a universal fact. While verification is a significant challenge, it is not empirically proven to be the *primary* bottleneck across all software development environments. For many organizations, the primary bottlenecks remain system architecture, integration debt, legacy code complexity, and human-to-human communication. Labeling verification as the singular "primary" bottleneck ignores the multifaceted nature of software engineering constraints.
#
# === ANALYSIS (analyst -- read the brief via context) ===
# {"executive_summary":"The shift toward autonomous AI agents in software development necessitates a transition from manual coding to architectural oversight and rigorous verification. Organizations must navigate significant security and integration challenges to effectively leverage these tools in production environments.","key_implications":["Security and governance risks are paramount, as granting autonomous agents write-access to repositories and execution environments creates significant exposure to unauthorized code injection and infrastructure damage.","The non-deterministic nature of agentic outputs complicates version control and auditability, requiring new standards for validating code generated by probabilistic models.","Integration debt remains a critical barrier, as the complexity of debugging agent-generated logic can negate the productivity gains achieved during the initial coding phase."],"recommendations":["Implement a mandatory human-in-the-loop verification protocol for all agent-generated commits to ensure logic accuracy and alignment with architectural standards.","Establish strict sandboxing and permission-based access controls for all AI agents to mitigate the risks associated with autonomous system interaction."]}
#
# === FINAL REPORT (writer -- read both via context) ===
# ### The Rise of Autonomous Coding: From Syntax to Strategy
#
# The landscape of software development is undergoing a fundamental shift. We are moving away from "copilot" models—which merely suggest snippets of code—toward autonomous AI agents. Unlike their predecessors, these agents can navigate file systems, execute terminal commands, and run test suites. By breaking down high-level prompts into sequences of sub-tasks, they act as independent operators capable of iterating on their own work to solve complex engineering problems.
#
# This transition marks the dawn of "Intent-Based Development." In this new paradigm, the developer’s role is evolving from a writer of syntax to an architect of constraints. Instead of typing every line, engineers now define the desired outcome and oversee the autonomous execution of the logic. Tools like Cursor or open-source initiatives like OpenDevin are already demonstrating how these systems can manage multi-file edits and environment interactions, effectively handling the heavy lifting of routine development tasks.
#
# However, this autonomy introduces significant friction. Because these models are probabilistic, they can produce non-deterministic results, making it difficult to maintain consistent version control. Furthermore, granting agents write-access to repositories creates substantial security risks, including the potential for unauthorized code injection. Perhaps most importantly, the complexity of debugging agent-generated logic can sometimes outweigh the time saved during the initial coding phase.
#
# As organizations integrate these agents into their workflows, the focus must shift toward rigorous verification. Success will not be measured by how much code an agent can generate, but by the strength of the human-in-the-loop protocols established to audit, sandbox, and validate that logic before it ever reaches production.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>

# %% [markdown]
# ## What just happened: context handoff
#
# You never passed the research text to the analyst by hand. Because `analysis_task` declared `context=[research_task]`, CrewAI injected the researcher's output into the analyst's prompt automatically; the writer got both. That is the crew handoff — coordination through `context` instead of manual argument passing.
#
# But notice: that context is **task-local**. It lives only for this one `kickoff()`. Run the crew again and it starts fresh with no memory of the last run. Enabling **memory** changes that.

# %% [markdown]
# ## Optional: enable CrewAI memory (context that survives across runs)
#
# Set `memory=True` on the Crew and CrewAI keeps short-term, long-term, and entity memory *across* `kickoff()` calls — so a later run can recall what earlier runs established. Because memory retrieves by similarity, it needs an **embedder**; we point it at Gemini's embedding model so the lab stays Gemini-only (the default embedder is OpenAI).
#
# The contrast to feel:
# - **Without memory** (above): every run is isolated — only task-local context within the run.
# - **With memory** (below): the crew accumulates a memory store that later runs read from.
#
# > **Heads-up:** memory + the embedder config can vary by CrewAI version and needs a live Colab run to confirm. If the embedder line errors, check the CrewAI memory docs for the provider/model names your installed version expects.
#
# > As above, we use `await memory_crew.kickoff_async()` because Colab has a running event loop.

# %%
memory_crew = Crew(
    agents=[researcher, analyst, writer],
    tasks=[research_task, analysis_task, writing_task],
    process=Process.sequential,
    memory=True,  # <-- turn on short-term / long-term / entity memory across runs
    embedder={
        # CrewAI renamed the Gemini embeddings provider: use "google-generativeai" (the Gemini API
        # path) -- "google-vertex" is the separate Vertex AI path, and the old bare "google" is gone.
        "provider": "google-generativeai",
        "config": {"api_key": api_key, "model_name": "gemini-embedding-001"},
    },
    verbose=False,
)

# Run 1 seeds the memory; Run 2 can recall it. (Same crew, run twice.)
try:
    print("--- Run 1 (seeds memory) ---")
    await memory_crew.kickoff_async()
    print(writing_task.output.raw[:300], "...")

    print("\n--- Run 2 (can recall Run 1 from memory) ---")
    await memory_crew.kickoff_async()
    print(writing_task.output.raw[:300], "...")
except Exception as e:
    if "503" in str(e):
        print("Gemini is under heavy load right now (repeated 503s); the memory demo could not finish.")
        print("This is a transient server-side issue -- wait a few minutes and re-run this cell.")
    else:
        raise
# Out:
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# --- Run 1 (seeds memory) ---
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ### The Rise of Autonomous AI Agents in Software Engineering
#
# Software development is undergoing a significant transformation. We are moving beyond passive tools that simply suggest code snippets toward "AI agents"—autonomous systems capable of executing complex, multi-step engineering tasks. Unlike ...
#
# --- Run 2 (can recall Run 1 from memory) ---
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ### The Rise of Autonomous AI Agents in Software Engineering
#
# The landscape of software development is undergoing a fundamental shift. We are moving beyond simple AI autocomplete tools toward autonomous "agents"—systems capable of executing complex, multi-step tasks with minimal human intervention.  ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Your turn (exercises)
#
# 1. **Add a fourth agent.** Insert a "Senior Fact-Checker" task between the researcher and the analyst that flags any claim the brief can't support; feed it forward with `context`.
# 2. **Structured handoff.** Give `analysis_task` an `output_pydantic` model so the writer receives typed, predictable analysis instead of prose.
# 3. **Swap the process.** Try `Process.hierarchical` (with a manager LLM) and observe how task delegation changes.
# 4. **Prove memory works.** With `memory=True`, run the crew on a topic, then run it again asking it to "build on what you found last time" and check whether Run 2 references Run 1.
# 5. **Compare to Lab 03A.** You built memory by hand there and got it from the framework here. Which was clearer? Which would you reach for in production, and why?
#
# When you're done, save a copy (**File -> Save a copy in Drive**) and submit your notebook link via Canvas.

# %% [markdown]
# ----

# %% [markdown]
# **Compare to Lab 03A. You built memory by hand there and got it from the framework here. Which was clearer? Which would you reach for in production, and why?**

# %% [markdown]
# For most Production tasks, the reduced boilerplate overhead achieved by using a framework such as CrewAI is preferable. Also, the fact that the CrewAI pipeline is much more standardized than the manually-built Reflexion pipeline is another factor that makes it more apprpropriate or Production.
# If need be, memory can easily be switched on in the CrewAI pipeline for multiple runs or left off to force each run to be independent, in contrast to the manual Reflexion pipeline.
# The manual Reflexion method may indeed be "clearer" because every bit of memory is manually persisted - in a markdown file, in this case - and thus available for inspection by humans, when comparted to the CrewAI method. But in terms of being Production-usable, that is not enough to make the manual method preferable.
